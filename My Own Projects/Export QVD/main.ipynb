# %%
import pandas as pd
from pyqvd import QvdTable

# 1. Create or load your data into a DataFrame
df = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie']
})

# 2. Convert DataFrame to a QvdTable object
qvd_table = QvdTable.f

# 3. Export to a .qvd file
qvd_table.to_qvd("my_exported_data.qvd")
