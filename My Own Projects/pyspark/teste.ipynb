# %%
import pyspark 
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("ExampleApp").getOrCreate()

date = [("João",25),("Maria",30),("Pedro",22)]

# %%
df = spark.createDataFrame(date,["Nome","Idade"])

# %%
print(spark.version)
# Out:
# 4.1.1
